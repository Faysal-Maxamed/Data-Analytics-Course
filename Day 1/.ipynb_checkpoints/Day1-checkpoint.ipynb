# %% [markdown]
# # load dataset
# ** Qeybtan waxa soo galin diinta data **

# %% [markdown]
# ** import library**

# %%
# import library pandas
# syntax for imprt (import Library_name as pd)
import pandas as pd

# %%
# read Data from Google Drive
data = pd.read_excel("/content/drive/MyDrive/Colab Notebooks/python/Excel_Project_Datasets_23_Assigned_Students_MORE_BLANKS_Abba_Muxidiin_Enrollment2222233344.xlsx")

# %% [markdown]
# understanding dataset

# %% [markdown]
# Reading data

# %%
data.head()
# Out:
#    No.              Student Name  \
# 0    1        Aba Muxudiin Ahmed
# 1    2      Abdikarim Ismail Ali
# 2    3  Abdinajib Abdullahi Muse
# 3    4   Aisha Mohamed Abdullahi
# 4    5       Aniso Ahmed Mohamud
#
#                                        Project Title      Dataset Sheet  Rows  \
# 0       Student Enrollment Data Analysis Using Excel      01_Enrollment   300
# 1  Customer Purchase & Sales Performance Analysis...           02_Sales   300
# 2      Employee Attendance Data Analysis Using Excel  03_Emp_Attendance   300
# 3  Restaurant Sales and Customer Analysis Using E...      04_Restaurant   300
# 4                                 TITLE NOT PROVIDED                NaN     0
#
#    Columns                Status  Unnamed: 7  \
# 0        7                 Ready         NaN
# 1        7                 Ready         NaN
# 2        7                 Ready         NaN
# 3        7                 Ready         NaN
# 4        0  Project title needed         NaN
#
# ...

# %%
data1 = pd.read_excel("/content/drive/MyDrive/Colab Notebooks/python/test.xlsx")

# %%
data1.head()
# Out:
#   Student_ID  Gender           Program      Enrollment_Date Study_Mode  \
# 0    ENR0001    Male  Computer Science  2025-12-03 00:00:00  Full-Time
# 1    ENR0002  Female  Computer Science  2025-04-25 00:00:00     Online
# 2    ENR0003    Male     Public Health  2026-03-24 00:00:00  Full-Time
# 3    ENR0004    Male      Data Science  2026-04-09 00:00:00  Part-Time
# 4    ENR0005  Female  Computer Science  2025-12-19 00:00:00  full-time
#
#   Tuition_Fee Enrollment_Status  Unnamed: 7  Unnamed: 8
# 0      927.99               NaN         NaN         NaN
# 1       929.8            Active         NaN         NaN
# 2     1028.35            Active         NaN         NaN
# 3         NaN            Active         NaN         NaN
# 4     1035.39            Active         NaN         NaN

# %%
data1.tail()
# Out:
#     Student_ID  Gender                  Program      Enrollment_Date  \
# 295        NaN    Male         Computer Science  2025-05-08 00:00:00
# 296        NaN  Female             Data Science  2025-07-09 00:00:00
# 297        NaN    Male             Data Science  2025-07-05 00:00:00
# 298        NaN  Female                Economics  2026-07-16 00:00:00
# 299        NaN  Female  Business Administration  2025-12-13 00:00:00
#
#     Study_Mode Tuition_Fee Enrollment_Status  Unnamed: 7  Unnamed: 8
# 295  Full-Time     1067.41            Active         NaN         NaN
# 296  Part-Time      1068.1            Active         NaN         NaN
# 297     Online     1057.04            Active         NaN         NaN
# 298     Online      753.39            Active         NaN         NaN
# 299     Online      901.18            Active         NaN         NaN

# %%
data1.sample(5)
# Out:
#     Student_ID  Gender           Program      Enrollment_Date Study_Mode  \
# 53     ENR0054    Male       Engineering  2025-01-28 00:00:00  Full-Time
# 51     ENR0052    Male  Computer Science  2025-11-22 00:00:00  Full-Time
# 182    ENR0189  Female  Computer Science  2025-12-02 00:00:00  Full-Time
# 25     ENR0027    Male  Computer Science  2025-09-28 00:00:00        NaN
# 232    ENR0240  Female       Engineering  2025-02-28 00:00:00  Full-Time
#
#     Tuition_Fee Enrollment_Status  Unnamed: 7  Unnamed: 8
# 53       1142.6            Active         NaN         NaN
# 51       928.88            Active         NaN         NaN
# 182      974.48            Active         NaN         NaN
# 25      1014.33         Graduated         NaN         NaN
# 232         NaN            Active         NaN         NaN

# %% [markdown]
# #show the display data shape

# %%
data1.shape
# Out:
# (300, 9)

# %% [markdown]
# this dataset 300 raws and 9 column

# %%
data1.columns
# Out:
# Index(['Student_ID', 'Gender', 'Program', 'Enrollment_Date', 'Study_Mode',
#        'Tuition_Fee', 'Enrollment_Status', 'Unnamed: 7', 'Unnamed: 8'],
#       dtype='object')

# %% [markdown]
# Display the datatype of my dataset using property

# %%
data1.dtypes
# Out:
# Student_ID            object
# Gender                object
# Program               object
# Enrollment_Date       object
# Study_Mode            object
# Tuition_Fee           object
# Enrollment_Status     object
# Unnamed: 7           float64
# Unnamed: 8           float64
# dtype: object

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Student_ID         285 non-null    object
#  1   Gender             285 non-null    object
#  2   Program            284 non-null    object
#  3   Enrollment_Date    283 non-null    object
#  4   Study_Mode         281 non-null    object
#  5   Tuition_Fee        285 non-null    object
#  6   Enrollment_Status  282 non-null    object
#  7   Unnamed: 7         0 non-null      float64
#  8   Unnamed: 8         1 non-null      float64
# dtypes: float64(2), object(7)
# memory usage: 21.2+ KB

# %% [markdown]
# display the describe

# %%
data1.describe(include="all")
# Out:
#        Student_ID  Gender           Program      Enrollment_Date Study_Mode  \
# count         285     285               284                  283        281
# unique        277       5                 9                  218          7
# top       ENR0199  Female  Computer Science  2025-11-26 00:00:00  Full-Time
# freq            2     148                73                    4        159
# mean          NaN     NaN               NaN                  NaN        NaN
# std           NaN     NaN               NaN                  NaN        NaN
# min           NaN     NaN               NaN                  NaN        NaN
# 25%           NaN     NaN               NaN                  NaN        NaN
# 50%           NaN     NaN               NaN                  NaN        NaN
# 75%           NaN     NaN               NaN                  NaN        NaN
# max           NaN     NaN               NaN                  NaN        NaN
#
# ...

# %%
data2 = pd.read_excel("/content/drive/MyDrive/Colab Notebooks/python/Project Excel.xlsx")

# %%
data2.head()
# Out:
#   Student_ID  Gender           Program      Enrollment_Date Study_Mode  \
# 0    ENR0001    Male  Computer Science  2025-12-03 00:00:00  Full-Time
# 1    ENR0002  Female  Computer Science  2025-12-04 00:00:00     Online
# 2    ENR0003    Male     Public Health  2025-12-05 00:00:00  Full-Time
# 3    ENR0004    Male      Data Science  2025-12-06 00:00:00  Part-Time
# 4    ENR0005  Female  Computer Science  2025-12-07 00:00:00  Full-Time
#
#    Tuition_Fee Enrollment_Status    Year  Monthly Clean_Enrollment_Date
# 0       927.99        non_status  2025.0     12.0            2025-12-03
# 1       929.80            Active  2025.0     12.0            2025-12-04
# 2      1028.35            Active  2025.0     12.0            2025-12-05
# 3         0.00            Active  2025.0     12.0            2025-12-06
# 4      1035.39            Active  2025.0     12.0            2025-12-07

# %%
data2.info
# Out:
# <bound method DataFrame.info of     Student_ID  Gender                  Program      Enrollment_Date  \
# 0      ENR0001    Male         Computer Science  2025-12-03 00:00:00
# 1      ENR0002  Female         Computer Science  2025-12-04 00:00:00
# 2      ENR0003    Male            Public Health  2025-12-05 00:00:00
# 3      ENR0004    Male             Data Science  2025-12-06 00:00:00
# 4      ENR0005  Female         Computer Science  2025-12-07 00:00:00
# ..         ...     ...                      ...                  ...
# 295    ENR0296    Male         Computer Science  2025-07-16 00:00:00
# 296    ENR0297  Female             Data Science  2025-07-17 00:00:00
# 297    ENR0298    Male             Data Science  2025-07-18 00:00:00
# 298    ENR0299  Female                Economics  2025-07-19 00:00:00
# 299    ENR0300  Female  Business Administration  2025-07-20 00:00:00
#
#     Study_Mode  Tuition_Fee Enrollment_Status    Year  Monthly  \
# ...

# %%
data2.describe()
# Out:
#        Tuition_Fee         Year     Monthly          Clean_Enrollment_Date
# count   300.000000   282.000000  282.000000                            282
# mean    936.408967  2025.248227    6.776596  2025-10-08 03:08:56.170212864
# min       0.000000  2025.000000    1.000000            2025-06-09 00:00:00
# 25%     846.597500  2025.000000    6.000000            2025-07-04 06:00:00
# 50%     969.845000  2025.000000    7.000000            2025-08-20 12:00:00
# 75%    1104.097500  2025.000000    8.000000            2025-12-23 18:00:00
# max    1379.030000  2026.000000   12.000000            2026-07-17 00:00:00
# std     284.424128     0.432752    3.190804                            NaN

# %%
data2.describe(include="all")
# Out:
#        Student_ID  Gender           Program Enrollment_Date Study_Mode  \
# count         300     300               300             300        300
# unique        300       5                 7             186          5
# top       ENR0300  Female  Computer Science        non_date  Full-Time
# freq            1     148                74              18        162
# mean          NaN     NaN               NaN             NaN        NaN
# min           NaN     NaN               NaN             NaN        NaN
# 25%           NaN     NaN               NaN             NaN        NaN
# 50%           NaN     NaN               NaN             NaN        NaN
# 75%           NaN     NaN               NaN             NaN        NaN
# max           NaN     NaN               NaN             NaN        NaN
# std           NaN     NaN               NaN             NaN        NaN
#
#         Tuition_Fee Enrollment_Status         Year     Monthly  \
# ...

# %%
data2.dtypes
# Out:
# Student_ID                       object
# Gender                           object
# Program                          object
# Enrollment_Date                  object
# Study_Mode                       object
# Tuition_Fee                     float64
# Enrollment_Status                object
# Year                            float64
# Monthly                         float64
# Clean_Enrollment_Date    datetime64[ns]
# dtype: object
