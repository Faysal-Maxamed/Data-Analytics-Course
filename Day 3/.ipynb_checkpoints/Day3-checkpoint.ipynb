# %%
import pandas as pd

# %%
data = pd.read_excel("/content/drive/MyDrive/Colab Notebooks/Enrollment_python.xlsx")

# %%
data.head()
# Out:
#   Student_ID  Gender                  Program      Enrollment_Date Study_Mode  \
# 0    ENR0123  Female         Computer Science  2026-01-06 00:00:00  Full-Time
# 1    ENR0050  Female            Public Health  2026-05-02 00:00:00  Full-Time
# 2    ENR0241  Female  Business Administration  2026-05-19 00:00:00        NaN
# 3    ENR0279  Female         Computer Science  2025-06-21 00:00:00  Full-Time
# 4    ENR0091    Male              Engineering  2025-10-03 00:00:00     Online
#
#   Tuition_Fee Enrollment_Status
# 0     1037.53         Graduated
# 1         NaN         Graduated
# 2      823.61         Graduated
# 3      998.42         Graduated
# 4     1358.18               NaN

# %%
data['Gender']
# Out:
# 0      Female
# 1      Female
# 2      Female
# 3      Female
# 4        Male
#         ...
# 295    Female
# 296    Female
# 297      Male
# 298    Female
# 299      Male
# Name: Gender, Length: 300, dtype: object

# %%
data.dtypes
# Out:
# Student_ID           object
# Gender               object
# Program              object
# Enrollment_Date      object
# Study_Mode           object
# Tuition_Fee          object
# Enrollment_Status    object
# dtype: object

# %%
data['Program'].value_counts()
# Out:
# Program
# Computer Science           73
# Data Science               65
# Business Administration    46
# Engineering                37
# Public Health              35
# Economics                  25
# Unknown                     1
# CS                          1
# BA                          1
# Name: count, dtype: int64

# %%
data.rename(columns={"Student_ID":"STD"})
# Out:
#          STD  Gender                  Program      Enrollment_Date Study_Mode  \
# 0    ENR0123  Female         Computer Science  2026-01-06 00:00:00  Full-Time
# 1    ENR0050  Female            Public Health  2026-05-02 00:00:00  Full-Time
# 2    ENR0241  Female  Business Administration  2026-05-19 00:00:00        NaN
# 3    ENR0279  Female         Computer Science  2025-06-21 00:00:00  Full-Time
# 4    ENR0091    Male              Engineering  2025-10-03 00:00:00     Online
# ..       ...     ...                      ...                  ...        ...
# 295  ENR0110  Female             Data Science  2026-03-12 00:00:00  Full-Time
# 296  ENR0246  Female         Computer Science  2025-06-13 00:00:00     Online
# 297  ENR0084    Male                Economics  2026-02-22 00:00:00  Full-Time
# 298  ENR0227  Female  Business Administration  2025-11-13 00:00:00  Part-Time
# 299  ENR0169    Male            Public Health  2025-11-20 00:00:00     Online
#
#     Tuition_Fee Enrollment_Status
# 0       1037.53         Graduated
# 1           NaN         Graduated
# 2        823.61         Graduated
# 3        998.42         Graduated
# 4       1358.18               NaN
# ..          ...               ...
# 295     1235.12            Active
# 296     1014.19            Active
# 297      804.04            Active
# 298      905.56          Deferred
# 299       886.5            Active
#
# [300 rows x 7 columns]

# %%
data['Program'] = data['Program'].replace("CS", "Computer Science")

# %%
data['Program'].value_counts()
# Out:
# Program
# Computer Science           74
# Data Science               65
# Business Administration    46
# Engineering                37
# Public Health              35
# Economics                  25
# Unknown                     1
# BA                          1
# Name: count, dtype: int64

# %%
data['Program'] = data['Program'].replace("BA", "Business Administration")

# %%
data['Program'].value_counts()
# Out:
# Program
# Computer Science           74
# Data Science               65
# Business Administration    47
# Engineering                37
# Public Health              35
# Economics                  25
# Unknown                     1
# Name: count, dtype: int64

# %%
data['Gender'].value_counts()
# Out:
# Gender
# Female    148
# Male      134
# male        1
# -           1
# MALE        1
# Name: count, dtype: int64

# %%
data['Gender'] = data['Gender'].replace("MALE", "Male")

# %%
data['Gender'].value_counts()
# Out:
# Gender
# Female    148
# Male      135
# male        1
# -           1
# Name: count, dtype: int64

# %%
data['Gender'] = data['Gender'].replace("male", "Male")

# %%
data['Gender'].value_counts()
# Out:
# Gender
# Female    148
# Male      136
# -           1
# Name: count, dtype: int64

# %%
data['Enrollment_Status'].value_counts()
# Out:
# Enrollment_Status
# Active       174
# Graduated     63
# Deferred      26
# Withdrawn     16
# ACTIVE         1
# graduated      1
# deferred       1
# Name: count, dtype: int64

# %%
data['Enrollment_Status'] = data['Enrollment_Status'].replace("ACTIVE", "Active")

# %%
data['Enrollment_Status'].value_counts()
# Out:
# Enrollment_Status
# Active       175
# Graduated     63
# Deferred      26
# Withdrawn     16
# graduated      1
# deferred       1
# Name: count, dtype: int64

# %%
data['Enrollment_Status'] = data['Enrollment_Status'].replace("graduated", "Graduated")

# %%
data['Enrollment_Status'].value_counts()
# Out:
# Enrollment_Status
# Active       175
# Graduated     64
# Deferred      26
# Withdrawn     16
# deferred       1
# Name: count, dtype: int64

# %%
data['Enrollment_Status'] = data['Enrollment_Status'].replace("deferred", "Deferred")

# %%
data['Enrollment_Status'].value_counts()
# Out:
# Enrollment_Status
# Active       175
# Graduated     64
# Deferred      27
# Withdrawn     16
# Name: count, dtype: int64

# %%
data['Study_Mode'].value_counts()
# Out:
# Study_Mode
# Full-Time    159
# Online        59
# Part-Time     58
# full-time      2
# FULL-TIME      1
# part-time      1
# online         1
# Name: count, dtype: int64

# %%
data.dtypes
# Out:
# Student_ID            object
# Gender                object
# Program               object
# Enrollment_Date       object
# Study_Mode            object
# Tuition_Fee          float64
# Enrollment_Status     object
# dtype: object

# %%
data['Tuition_Fee'] = data['Tuition_Fee'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_884/723229054.py in <cell line: 0>()
# ----> 1 data['Tuition_Fee'] = data['Tuition_Fee'].astype(float)
#
# /usr/local/lib/python3.13/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    6641         else:
#    6642             # else, only a single dtype is given
# -> 6643             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644             res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645             return res.__finalize__(self, method="astype")
#
# /usr/local/lib/python3.13/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     428             copy = False
#     429
# --> 430         return self.apply(
#     431             "astype",
#     432             dtype=dtype,
#
# /usr/local/lib/python3.13/dist-packages/pandas/core/internals/managers.py in apply(self, f, align_keys, **kwargs)
#     361                 applied = b.apply(f, **kwargs)
#     362             else:
# --> 363                 applied = getattr(b, f)(**kwargs)
#     364             result_blocks = extend_blocks(applied, result_blocks)
#     365
#
# /usr/local/lib/python3.13/dist-packages/pandas/core/internals/blocks.py in astype(self, dtype, copy, errors, using_cow, squeeze)
#     756             values = values[0, :]  # type: ignore[call-overload]
#     757
# --> 758         new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     759
#     760         new_values = maybe_coerce_values(new_values)
#
# /usr/local/lib/python3.13/dist-packages/pandas/core/dtypes/astype.py in astype_array_safe(values, dtype, copy, errors)
#     235
#     236     try:
# --> 237         new_values = astype_array(values, dtype, copy=copy)
#     238     except (ValueError, TypeError):
#     239         # e.g. _astype_nansafe can fail on object-dtype of strings
#
# /usr/local/lib/python3.13/dist-packages/pandas/core/dtypes/astype.py in astype_array(values, dtype, copy)
#     180
#     181     else:
# --> 182         values = _astype_nansafe(values, dtype, copy=copy)
#     183
#     184     # in pandas we don't store numpy str dtypes, so convert to object
#
# /usr/local/lib/python3.13/dist-packages/pandas/core/dtypes/astype.py in _astype_nansafe(arr, dtype, copy, skipna)
#     131     if copy or arr.dtype == object or dtype == object:
#     132         # Explicit copy, or required since NumPy can't view from / to object.
# --> 133         return arr.astype(dtype, copy=True)
#     134
#     135     return arr.astype(dtype, copy=copy)
#
# ValueError: could not convert string to float: '-'

# %%
data['Tuition_Fee'] = pd.to_numeric(
    data['Tuition_Fee'],
    errors="coerce"
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2124/1932120192.py in <cell line: 0>()
# ----> 1 data['Tuition_Fee'] = pd.to_numeric(
#       2     data['Tuition_Fee'],
#       3     errors="coerce"
#       4 )
#
# NameError: name 'pd' is not defined
